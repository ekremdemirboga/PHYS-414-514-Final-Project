# %%
import M_R_curve_for_NS as MR
import M_vs_K as MK

##Plots all figures in Einstein part and prints all the information takes a bit time to find the max K
MR.M_R_curve()
MK.max_K()
# Out:
# /home/ekrem/Ekrem/Einstein/tov_solver.py:8: RuntimeWarning: invalid value encountered in double_scalars
#   rho = (p/K)**(1/Gamma)
# maximum mass is :  1.410421107619103
