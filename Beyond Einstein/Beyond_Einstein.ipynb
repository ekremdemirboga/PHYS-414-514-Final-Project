# %%
import Wave_Equation_solver as wave
import wave_equation_with_added_term as wave2

wave.wave_equation()

wave2.modified_wave_equation()
# Out:
# /home/ekrem/Ekrem/Beyond Einstein/tov_solver.py:8: RuntimeWarning: invalid value encountered in double_scalars
#   rho = (p/K)**(1/Gamma)
# /home/ekrem/Ekrem/Beyond Einstein/Wave_Equation_solver.py:40: RuntimeWarning: divide by zero encountered in true_divide
#   return 1/r**2
# /home/ekrem/Ekrem/Beyond Einstein/Wave_Equation_solver.py:36: RuntimeWarning: invalid value encountered in true_divide
#   return np.exp(M(r)/2)*(1 - 2*v(r)/r)**(1/2)
# /home/ekrem/Ekrem/Beyond Einstein/wave_equation_with_added_term.py:50: RuntimeWarning: divide by zero encountered in true_divide
#   return 1/r**2
# /home/ekrem/Ekrem/Beyond Einstein/wave_equation_with_added_term.py:46: RuntimeWarning: invalid value encountered in true_divide
#   return np.exp(M(r)/2)*(1 - 2*v(r)/r)**(1/2)
