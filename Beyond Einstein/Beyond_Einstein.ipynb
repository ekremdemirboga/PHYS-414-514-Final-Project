# %%
import Wave_Equation_solver as wave
import wave_equation_with_added_term as wave2


for rho in [1e-3, 5e-4, 1e-4]:
    print("for rho_c ={} ".format)
    wave.wave_equation(rho_c = rho)
    wave2.modified_wave_equation(rho_c = rho)
# Out:
# <built-in method format of str object at 0x7f4b9e680370>
# /home/ekrem/Ekrem/Beyond Einstein/tov_solver.py:8: RuntimeWarning: invalid value encountered in double_scalars
#   rho = (p/K)**(1/Gamma)
# /home/ekrem/Ekrem/Beyond Einstein/Wave_Equation_solver.py:37: RuntimeWarning: divide by zero encountered in true_divide
#   return 1/r**2
# /home/ekrem/Ekrem/Beyond Einstein/Wave_Equation_solver.py:33: RuntimeWarning: invalid value encountered in true_divide
#   return np.exp(M(r)/2)*(1 - 2*v(r)/r)**(1/2)
# /home/ekrem/Ekrem/Beyond Einstein/wave_equation_with_added_term.py:46: RuntimeWarning: divide by zero encountered in true_divide
#   return 1/r**2
# /home/ekrem/Ekrem/Beyond Einstein/wave_equation_with_added_term.py:42: RuntimeWarning: invalid value encountered in true_divide
#   return np.exp(M(r)/2)*(1 - 2*v(r)/r)**(1/2)
# <built-in method format of str object at 0x7f4b9e680370>
# <built-in method format of str object at 0x7f4b9e680370>
